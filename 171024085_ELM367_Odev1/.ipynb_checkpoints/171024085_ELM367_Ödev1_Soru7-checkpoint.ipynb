# %% [markdown]
# ### Adı Soyadı: Ömer Konan
# ### Öğrenci No: 171024085
# ### ELM367 Ödev #1

# %% [markdown]
# # Soru 7

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
# Jupyter Notebook'ta şekillerin görünmesini sağlamak için gerekli:
# %matplotlib notebook


#2.7 a için çizim
pi = np.pi
n_a = np.arange(0,30)
angle_a = n_a*np.pi/6
x_a = np.exp(1j*angle_a)
    
plt.stem(n_a, x_a, use_line_collection=True)
plt.title('$Soru7)--2.7.a) e^{j(\pi*n/6)}$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/konan/.local/lib/python3.6/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
n_d = np.arange(0,30)
x_d = np.exp(1j*n)

plt.figure()
plt.stem(n_d, x_d, use_line_collection=True)
plt.title('$Soru7)--2.40.d) e^{jn}$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-97dd40c81a74> in <module>
#       1 n_d = np.arange(0,30)
# ----> 2 x_d = np.exp(1j*n)
#       3
#       4 plt.figure()
#       5 plt.stem(n_d, x_d, use_line_collection=True)
#
# NameError: name 'n' is not defined
