# %% [markdown]
# ### Adı Soyadı: Ömer Konan
# ### Öğrenci No: 171024085
# ### ELM367 Ödev #1

# %% [markdown]
# # Soru 8

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# Jupyter Notebook'ta şekillerin görünmesini sağlamak için gerekli:
# %matplotlib notebook 

pi = np.pi
n_ = np.arange(0,99)
x = (np.sin(pi*n/20)) \
  + (np.sin(3*pi*n/20)/3) \
  + (np.sin(pi*n/5)/5)

    
plt.figure()
plt.stem(n,x, use_line_collection=True)
plt.title("Soru 8) $x[n] = \sin(\pi n/20)+ \sin(3 \pi n/20)/3+ \sin(\pi n/5)/5$")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
