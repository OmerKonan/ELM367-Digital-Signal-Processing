# %% [markdown]
# ### Adı Soyadı: Ömer Konan
# ### Öğrenci No: 171024085
# ### ELM367 Ödev #3

# %% [markdown]
# # Soru 8

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
# Jupyter Notebook'ta şekillerin görünmesini sağlamak için gerekli:
# %matplotlib notebook

# %%
alpha = -0.5
w = np.linspace(-np.pi, np.pi, 10000)
X = 1 / (1 - alpha * np.exp(-1j * w))

plt.plot(w, np.abs(x), color='b',  label='Genlik')
plt.plot(w, np.angle(x), color='g', label='Faz')

plt.legend()

plt.show()
